# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Requirement already satisfied: torchtext in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.9.0+cu111)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchtext) (3.7.4.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.3 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Collecting es_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz (16.2 MB)
#      |████████████████████████████████| 16.2 MB 5.4 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from es_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# --2021-10-21 21:34:00--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.1s
#
# 2021-10-21 21:34:00 (80.0 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2021-10-21 21:34:00--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.09s
#
# 2021-10-21 21:34:00 (83.6 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask, d_k):
    # Compute 'Scaled Dot Product Attention'
    scores = torch.bmm(query, torch.transpose(key, 1, 2))/(d_k**.5)
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    output = torch.bmm(torch.softmax(scores, 1), value)
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.h = h
        self.d_model = d_model
        self.d_k = int(d_model/h)
        # Make an attention head (linear layers for q, k, and v)
        self.qlinear = nn.Linear(d_model, self.d_k)
        self.klinear = nn.Linear(d_model, self.d_k)
        self.vlinear = nn.Linear(d_model, self.d_k)
        self.olinear = nn.Linear(h*self.d_k, d_model)
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.qheads = clones(self.qlinear, h)
        self.kheads = clones(self.klinear, h)
        self.vheads = clones(self.vlinear, h)
        # etc.

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        # etc.
        outputs = []
        for i in range(self.h):
            q = self.qheads[i](query)
            k = self.kheads[i](key)
            v = self.vheads[i](value)
            output = attention(q, k, v, mask, self.d_k)
            outputs.append(output)
        return self.olinear(torch.cat(outputs, 2))

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.legacy.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.legacy.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.708693 Tokens per Sec: 2616.002930
# Epoch Step: 51 Loss: 5.627347 Tokens per Sec: 5249.084961
# Epoch Step: 101 Loss: 5.571900 Tokens per Sec: 5160.162109
# Epoch Step: 151 Loss: 5.012726 Tokens per Sec: 5144.179199
# Epoch Step: 201 Loss: 4.878626 Tokens per Sec: 5045.391113
# Epoch Step: 251 Loss: 4.734305 Tokens per Sec: 5421.705566
# Epoch Step: 301 Loss: 4.468254 Tokens per Sec: 5290.568359
# Epoch Step: 351 Loss: 4.562407 Tokens per Sec: 5262.602051
# Epoch Step: 401 Loss: 5.014782 Tokens per Sec: 5194.902832
# Epoch Step: 451 Loss: 4.347789 Tokens per Sec: 5294.971191
# Epoch Step: 501 Loss: 4.271533 Tokens per Sec: 5201.991211
# Epoch Step: 551 Loss: 4.181437 Tokens per Sec: 5096.025879
# Epoch Step: 601 Loss: 4.271474 Tokens per Sec: 5124.764648
# Epoch Step: 651 Loss: 4.755597 Tokens per Sec: 5084.362305
# Epoch Step: 701 Loss: 4.286646 Tokens per Sec: 5003.082520
# Epoch Step: 751 Loss: 3.919947 Tokens per Sec: 5260.810547
# Epoch Step: 801 Loss: 4.069106 Tokens per Sec: 5347.655273
# Epoch Step: 851 Loss: 3.874365 Tokens per Sec: 5320.567871
# Epoch Step: 901 Loss: 3.699688 Tokens per Sec: 5367.882812
# Epoch Step: 951 Loss: 3.247123 Tokens per Sec: 5361.617676
# Epoch Step: 1001 Loss: 3.935196 Tokens per Sec: 5336.588379
# Epoch Step: 1051 Loss: 3.456808 Tokens per Sec: 5385.738281
# Epoch Step: 1101 Loss: 3.470425 Tokens per Sec: 5352.743652
# Epoch Step: 1151 Loss: 3.064613 Tokens per Sec: 5364.053223
# Epoch Step: 1201 Loss: 3.055047 Tokens per Sec: 5391.210938
# Epoch Step: 1251 Loss: 3.793855 Tokens per Sec: 5108.537598
# Epoch Step: 1301 Loss: 3.445055 Tokens per Sec: 5196.441406
# Epoch Step: 1 Loss: 2.900971 Tokens per Sec: 3062.243896
# Epoch Step: 51 Loss: 3.329055 Tokens per Sec: 5246.787109
# Epoch Step: 851 Loss: 1.468867 Tokens per Sec: 5198.245605
# Epoch Step: 901 Loss: 1.416802 Tokens per Sec: 5249.241699
# Epoch Step: 951 Loss: 1.500101 Tokens per Sec: 5238.518066
# Epoch Step: 1001 Loss: 1.149294 Tokens per Sec: 5349.543457
# Epoch Step: 1051 Loss: 1.666824 Tokens per Sec: 4972.058105
# Epoch Step: 1101 Loss: 1.432907 Tokens per Sec: 5197.279785
# Epoch Step: 1151 Loss: 1.062363 Tokens per Sec: 5221.647461
# Epoch Step: 1201 Loss: 0.932048 Tokens per Sec: 5234.823242
# Epoch Step: 1251 Loss: 0.853929 Tokens per Sec: 5269.266602
# Epoch Step: 1301 Loss: 0.877586 Tokens per Sec: 5154.342773

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	De los Setenta
# Translation:
# Target:		Of the Seventy
#
# Spanish:	Él dijo :
# Translation:
# Target:		Said He :
#
# Spanish:	Véase Lucas 2:41–52 .
# Translation:
# Target:		See Luke 2:41–52 .
#
# Spanish:	Véase Helamán 5:12 .
# Translation:
# Target:		See Helaman 5:12 .
#
# Spanish:	Por Neill F. Marriott
# Translation:
# Target:		By Neill F. Marriott
#
# Spanish:	No debemos demorar .
# Translation:
# Target:		We must not delay .
#
# Spanish:	Cosas concernientes a la rectitud
# Translation:
# Target:		Things <unk> to Righteousness
#
# Spanish:	Yo no lo veía .
# Translation:
# Target:		I did not see .
#
# Spanish:	Doctrina y Convenios 76:22–23 .
# Translation:
# Target:		Doctrine and Covenants 76:22–23 .
#
# Spanish:	Véase 3 Nefi <unk> .
# Translation:
# Target:		See 3 Nephi <unk> .
#
# Spanish:	Los avergonzaron y <unk> .
# Translation:
# Target:		They shamed and <unk> them .
#
# Spanish:	Aún no he podido .
# Translation:
# Target:		Still ca n’t . I spent three solid days thinking about Him .
#
# Spanish:	¡ Pero no fue así !
# Translation:
# Target:		But no !
#
# Spanish:	1 . Aprender nuestro deber .
# Translation:
# Target:		1 . Learning Our Duty
#
# Spanish:	Por el élder Donald L. Hallstrom
# Translation:
# Target:		By Elder Donald L. Hallstrom
#
# Spanish:	Véase D. y C. 121:26 .
# Translation:
# Target:		See Doctrine and Covenants 121:26 .
#
# Spanish:	¿ Por qué lo hizo ?
# Translation:
# Target:		Why did He do it ?
#
# Spanish:	¡ Su destino es glorioso !
# Translation:
# Target:		Your destiny is a glorious one !
#
# Spanish:	Del Quórum de los Doce Apóstoles
# Translation:
# Target:		Of the Quorum of the Twelve Apostles
#
# Spanish:	Jóvenes que todavía no se han bautizado
# Translation:
# Target:		Youth Not Yet Baptized
#
# Spanish:	¿ Qué les sucede ? ” .
# Translation:
# Target:		What happened to you ? ”
#
# Spanish:	Isaías 2:3 ; 2 Nefi 12:3 .
# Translation:
# Target:		Isaiah 2:3 ; 2 Nephi 12:3 .
#
# Spanish:	3 Nefi 19:25 ; cursiva agregada .
# Translation:
# Target:		3 Nephi 19:25 ; emphasis added .
#
# Spanish:	tenía excelentes consejeros en el obispado .
# Translation:
# Target:		He had excellent counselors in his bishopric .
#
# Spanish:	Quizás podríamos empezar haciéndonos estas preguntas :
# Translation:
# Target:		Perhaps we could start by asking ourselves these questions :
#
# Spanish:	¡ Echen a los <unk> de allí !
# Translation:
# Target:		<unk> the <unk> out !
#
# Spanish:	“ ¿ Es usted mormón ? ” .
# Translation:
# Target:		“ Are you a Mormon ? ”
#
# Spanish:	¿ Cómo se sienten acerca de Jesucristo ?
# Translation:
# Target:		How do you feel about Jesus Christ ?
#
# Spanish:	Oré después de leer detenidamente cada párrafo .
# Translation:
# Target:		I prayed after carefully reading each paragraph .
#
# Spanish:	No nos demoremos en esta gran causa .
# Translation:
# Target:		Let us not delay in this great cause .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Dime la historia de Cristo , hazme sentir
# Translation:
# Target:		Tell me the stories of Jesus I love to hear ,
#
# Spanish:	en que encontramos lo eterno de cada día .
# Translation:
# Target:		One meets the eternal Everyday .
#
# Spanish:	Como el élder Jeffrey R. Holland ha enseñado :
# Translation:
# Target:		As Elder Jeffrey R. Holland has taught :
#
# Spanish:	Sigan las enseñanzas y el ejemplo de Jesucristo .
# Translation:
# Target:		Follow the teachings and example of Jesus Christ .
#
# Spanish:	Véase Doctrina y Convenios <unk> ; Moisés 7:37 .
# Translation:
# Target:		See Doctrine and Covenants <unk> ; Moses 7:37 .
#
# Spanish:	El hombre dijo : “ Ahora estoy confundido .
# Translation:
# Target:		The man said , “ Now I ’m confused .
#
# Spanish:	Doy firme testimonio de que el Salvador vive .
# Translation:
# Target:		I bear my sure witness that the Savior lives .
#
# Spanish:	Podemos saber qué hacer para resolver nuestros problemas .
# Translation:
# Target:		We can know what we should do to solve our problems .
#
# Spanish:	Divina Luz , entre las penumbras , <unk> .
# Translation:
# Target:		Lead , kindly Light , amid <unk> ’ encircling gloom ; Lead thou me on !
#
# Spanish:	había algo en ellos que me conmovió el corazón .
# Translation:
# Target:		Something about them warmed my heart .
#
# Spanish:	Tal vez ya sepan que tienen el deber de :
# Translation:
# Target:		You may already know that you are to :
#
# Spanish:	Cada una de ustedes debe tener su propio ejemplar .
# Translation:
# Target:		Each of you should have your own copy .
#
# Spanish:	Él ha confiado a su cuidado Sus hijos eternos .
# Translation:
# Target:		He has entrusted to your care His eternal children .
#
# Spanish:	Algunas de las respuestas que me han dado son :
# Translation:
# Target:		Some of the answers you have given me include :
#
# Spanish:	¿ Qué recompensa dará el hombre por su alma ?
# Translation:
# Target:		What Shall a Man Give in <unk> for His Soul ?
#
# Spanish:	Nefi lo presentó en el primer capítulo del libro .
# Translation:
# Target:		Nephi introduced it in the very first chapter of the book .
#
# Spanish:	Lo <unk> , <unk> y <unk> de su ciudad .
# Translation:
# Target:		They reviled him , ridiculed him , and cast him out of their city .
#
# Spanish:	[ y ] ¿ Podéis sentir esto ahora ? ” .
# Translation:
# Target:		And can you feel it now ? ”
#
# Spanish:	Véase Putnam and Campbell , American Grace , pág. 504 .
# Translation:
# Target:		See Putnam and Campbell , American Grace , <unk> .
#
# Spanish:	Doctrina y Convenios 104:16 ; véase también el versículo 15 .
# Translation:
# Target:		Doctrine and Covenants 104:16 ; see also verse 15 .
#
# Spanish:	Su otra hija estaba en su primera semana de <unk> .
# Translation:
# Target:		Her other child was in her first week of <unk> .
#
# Spanish:	Es el único camino perfecto para tener paz y felicidad .
# Translation:
# Target:		It is the one perfect path to peace and happiness .
#
# Spanish:	No existe carga que Él no pueda aliviar o quitar .
# Translation:
# Target:		There is no burden that He can not ease or remove .
#
# Spanish:	Hoy nos hemos reunido como un vasto cuerpo del sacerdocio .
# Translation:
# Target:		Today we are assembled as a vast body of the priesthood .
#
# Spanish:	Debido a Su gran amor , Jesucristo expió nuestros pecados .
# Translation:
# Target:		Because of His great love , Jesus Christ atoned for our sins .
#
# Spanish:	‘ No me importa ; no me quedaré aquí ’ .
# Translation:
# Target:		‘ I do n’t care , I am not going to stay here . ’
#
# Spanish:	¿ Qué hay de aquellos que mueren a una tierna edad ?
# Translation:
# Target:		What about those who die so very young ?
#
# Spanish:	Nosotros también tenemos el privilegio de vivir en una época excepcional .
# Translation:
# Target:		We too are privileged to live in an exceptional time .
#
# Spanish:	Aunque podamos estar en desacuerdo , no es apropiado ser desagradables .
# Translation:
# Target:		Though we may disagree , we should not be disagreeable .
#
# Spanish:	Dos hermanas que conocí recientemente representan la forma de vivir fielmente .
# Translation:
# Target:		Two sisters I have met recently represent how to live faithfully .
#
# Spanish:	Su naturaleza había cambiado y deseaba lo mismo que el Salvador .
# Translation:
# Target:		His nature had been changed to want what the Savior wanted .
#
# Spanish:	Los que esperen la venida del Salvador lo “ buscarán ” .
# Translation:
# Target:		Those awaiting the Savior ’s coming will “ look for Him . ”
#
# Spanish:	Sabíamos que pecaríamos y cometeríamos errores , incluso quizás algunos graves ;
# Translation:
# Target:		We knew we would sin and make mistakes — perhaps even serious ones .
#
# Spanish:	Sentí consuelo mediante sus inquebrantables testimonios del Salvador y Su plan .
# Translation:
# Target:		I was comforted by your infallible testimonies of the Savior and His plan .
#
# Spanish:	En ese sagrado santuario encontraremos paz , seremos renovados y fortalecidos .
# Translation:
# Target:		In this sacred sanctuary we will find peace ; we will be renewed and fortified .
#
# Spanish:	¡ Amamos a los Santos de los Últimos Días de todas partes !
# Translation:
# Target:		We love the Latter - day Saints everywhere !
#
# Spanish:	Todos , en cualquier llamamiento , en cualquier puesto , son importantes .
# Translation:
# Target:		Everyone , every position , and every calling is important .
#
# Spanish:	Con ese resplandor , será mejor que se preparen para las preguntas .
# Translation:
# Target:		With that radiance , you had better prepare for questions .
#
# Spanish:	Su meta es la vida eterna en el reino de nuestro Padre .
# Translation:
# Target:		Eternal life in the kingdom of our Father is your goal .
#
# Spanish:	Me encanta el testimonio de nuestra poetisa y amiga Emma Lou Thayne .
# Translation:
# Target:		I love the testimony of our poetess and friend Emma Lou Thayne .
#
# Spanish:	Hace algunos años , John fue aceptado en una <unk> universidad japonesa .
# Translation:
# Target:		Some years ago , John was accepted at a prestigious Japanese university .
#
# Spanish:	Se debe a que es un mandamiento del Señor , quien dijo :
# Translation:
# Target:		It is because of a commandment from the Lord , who said :
#
# Spanish:	Ninguno de nosotros podría servir sin sus oraciones ni sin su apoyo .
# Translation:
# Target:		Not one of us could serve without your prayers and without your support .
#
# Spanish:	En este sentido rindo un tributo personal al presidente Thomas Spencer Monson .
# Translation:
# Target:		In that regard , I pay a personal tribute to President Thomas Spencer Monson .
#
# Spanish:	En el templo nos preparamos y prometemos vivir la ley de consagración .
# Translation:
# Target:		In the temple we are prepared to and promise to live the law of consecration .
#
# Spanish:	Tim se bautizó y él y Charlene se sellaron en el templo .
# Translation:
# Target:		Tim has now been baptized , and he and Charlene have been sealed in the temple .
#
# Spanish:	percibió que una de las ruedas <unk> pasaba por encima de un bulto .
# Translation:
# Target:		He felt his back tire roll over a <unk> .
#
# Spanish:	Elegir la ubicación geográfica para un templo no siempre es una decisión sencilla .
# Translation:
# Target:		The location of a temple is not a convenient geographical decision .
#
# Spanish:	“ Cuando papá vuelve ” , Canciones para los niños , pág. 110 .
# Translation:
# Target:		“ Daddy ’s Homecoming , ” Children ’s Songbook , 210 .
#
# Spanish:	Carta de Jennifer Richards a Marvin Sabin , 5 de julio de 2009 .
# Translation:
# Target:		Jennifer Richards , letter to Marvin Sabin , July 5 , 2009 .
#
# Spanish:	Sin el espíritu , el cuerpo está muerto ( véase Santiago 2:26 ) .
# Translation:
# Target:		Without the spirit , the body is dead ( see James 2:26 ) .
#
# Spanish:	La última oración la ofrecerá el élder Hugo Montoya , de los Setenta .
# Translation:
# Target:		The benediction will then be offered by Elder Hugo Montoya of the Seventy .
#
# Spanish:	Un consejo de nuestros santos oró para saber qué actividad de servicio planificar .
# Translation:
# Target:		A council of your fellow Saints prayed to know what service to plan .
#
# Spanish:	Su compasión infinita puede ayudarnos a hallar nuestro camino , verdad y vida .
# Translation:
# Target:		His infinite compassion can help us find our way , truth , and life .
#
# Spanish:	Llegamos a conocer al Padre cuando llegamos a conocer a Su Hijo Amado .
# Translation:
# Target:		We come to know the Father as we come to know His Beloved Son .
#
# Spanish:	¿ Hay algo en tu vida que necesites cambiar y arreglar ya mismo ?
# Translation:
# Target:		Is there anything in your life you need to change and fix , beginning tonight ?
#
# Spanish:	Las dificultades que llegan presentan la verdadera prueba a nuestra capacidad de perseverar .
# Translation:
# Target:		The difficulties which come to us present us with the real test of our ability to endure .
#
# Spanish:	Nuestras obras y deseos por sí solos no nos salvan ni pueden hacerlo .
# Translation:
# Target:		In truth , we can not be good enough or measure up relying solely upon our own capacity and performance .
#
# Spanish:	Si la acción no se lleva a cabo , el compromiso es <unk> ” .
# Translation:
# Target:		Without the completed action , the commitment is hollow . ”
#
# Spanish:	A cada uno de nosotros se nos ha dado el don del albedrío moral .
# Translation:
# Target:		Each of us has been given the gift of moral agency .
#
# Spanish:	¿ Cómo era posible que una mañana luminosa <unk> aquel <unk> y tenebroso invierno ?
# Translation:
# Target:		How could that brutal dark winter be replaced with one brilliant morning ?
#
# Spanish:	Los relatos de cómo él presta atención a los susurros del Espíritu son muchos .
# Translation:
# Target:		The stories of his attention to the whisperings of the Spirit are numerous .
#
# Spanish:	Para describir su experiencia en el templo , ellos <unk> frases como las siguientes :
# Translation:
# Target:		They used phrases like the following to describe their experience in the temple :
#
# Spanish:	He observado tres características comunes de los poseedores del sacerdocio que eran mis héroes .
# Translation:
# Target:		I have observed three common characteristics of the priesthood holders who are my heroes .
#
# Spanish:	Cerca del final de Su ministerio mortal , el Salvador oró a Su Padre :
# Translation:
# Target:		Near the end of His mortal ministry , the Savior prayed to His Father :
#
# Spanish:	<unk> después al manual , y allí se encontraba la respuesta a mi pregunta .
# Translation:
# Target:		We then went to the handbook , and there was the answer to my question .
#
# Spanish:	Somos liberados mediante el amor , la gracia y el sacrificio expiatorio del Salvador .
# Translation:
# Target:		We are liberated by the love , grace , and atoning sacrifice of the Savior .
#
# Spanish:	Me encanta Moroni , porque en una sociedad deteriorada él permaneció puro y leal .
# Translation:
# Target:		I love Moroni because , in a very <unk> society , he remained pure and true .
#
# Spanish:	Por tanto , levantad vuestras cabezas y regocijaos , y poned vuestra confianza en Dios
# Translation:
# Target:		Therefore , lift up your heads , and rejoice , and put your trust in God .
#
# Spanish:	Él fue al monte a orar , y pasó la noche orando a Dios .
# Translation:
# Target:		He went out into a mountain to pray , and continued all night in prayer to God .
#
# Spanish:	Testifico que Él vive ; y lo hago en Su santo nombre . Amén .
# Translation:
# Target:		I testify that He lives and bear this witness in His holy name , the name of Jesus Christ , amen .
#
# Spanish:	De hecho , Susan y yo estábamos en el mismo camino de regreso a casa .
# Translation:
# Target:		Susan and I were actually on the same path back home .
#
# Spanish:	Pero , ¿ cómo puede algo relacionado con el temor ser edificante o espiritualmente útil ?
# Translation:
# Target:		But how can anything associated with fear be edifying or spiritually helpful ?
#
# Spanish:	Hágase tu voluntad , como en el cielo , así también en la tierra ” .
# Translation:
# Target:		Thy will be done in earth , as it is in heaven . ”
#
# Spanish:	Sin embargo , al final , un Dios amoroso y comprensivo lo confiere sobre nosotros .
# Translation:
# Target:		Ultimately , however , a loving and caring God bestows the gift upon us .
#
# Spanish:	Existe el riesgo de que alguien piense que no es lo suficientemente digno para orar .
# Translation:
# Target:		There is a risk that a person may not feel good enough to pray .
#
# Spanish:	Moisés congregó a los hijos de Israel y les enseñó los mandamientos que había recibido .
# Translation:
# Target:		Moses gathered the children of Israel and taught them the commandments he had received .
#
# Spanish:	Se determinó que tenía piedras en los riñones y se le recetó el tratamiento adecuado .
# Translation:
# Target:		It was determined that he had a kidney stone , and appropriate treatment was undertaken .
#
# Spanish:	No es una experiencia ficticia ni el efecto de “ … una mente desvariada ” .
# Translation:
# Target:		It is not a fictional experience or the product “ of a frenzied mind . ”
#
# Spanish:	“ Él les hablará a ellos en sueños , visiones , pensamientos y sentimientos ” .
# Translation:
# Target:		“ He will speak to them in dreams , visions , thoughts , and feelings . ”
#
# Spanish:	Vi santidad en el semblante de Evangeline , una joven de trece años de Ghana .
# Translation:
# Target:		I saw holiness in the countenance of Evangeline , a 13-year - old girl in Ghana .
#
# Spanish:	Él desea que estemos seguros y protegidos de las influencias del mundo a nuestro alrededor .
# Translation:
# Target:		He wants us to be safe and to be protected from the worldly influences all around us .
#
# Spanish:	Como Autoridad General recordará los árboles de Navidad y las enseñanzas que recibió de ellos .
# Translation:
# Target:		As a General Authority he will remember the Christmas trees and the lessons he learned from them .
#
# Spanish:	Recordarán Sus palabras cuando aconsejó que , al tener fe en Él , debemos arrepentirnos :
# Translation:
# Target:		You remember His words when He counseled that we should , out of faith in Him , repent :
#
# Spanish:	En el nombre de nuestro Salvador y Redentor Jesucristo , a quien servimos . Amén .
# Translation:
# Target:		In the name of our Savior and Redeemer , whom we serve , even Jesus Christ , the Lord , amen .
#
# Spanish:	Al comienzo de la Escuela Dominical se invitó a Diane a pasar a un salón vacío .
# Translation:
# Target:		As Sunday School began , Diane was invited to an empty classroom .
#
# Spanish:	Aquel joven se estaba convirtiendo cada vez más , al igual que sus compañeros de clase .
# Translation:
# Target:		This young man was becoming more converted , and so were his classmates .
#
# Spanish:	Debido a ello , decidí acelerar el proceso de curación haciendo mi propia investigación en internet .
# Translation:
# Target:		Consequently I decided to expedite the healing process by undertaking my own Internet search .
#
# Spanish:	La naturaleza divina infunde en nosotras el deseo de saber esas verdades eternas por nosotras mismas .
# Translation:
# Target:		Divine nature breathes into us the desire to know these eternal truths for ourselves .
#
# Spanish:	Más tarde , Kelly Clark se unió a Torah en el podio como medallista de bronce .
# Translation:
# Target:		Kelly Clark would later join Torah on the winners ’ podium as a bronze <unk> .
#
# Spanish:	Había sido una hermosa primavera para las comunidades que <unk> fruta en el norte de México .
# Translation:
# Target:		It had been a beautiful spring for the fruit - growing communities in northern Mexico .
#
# Spanish:	Luego de sus palabras , el coro cantará : " Mi Padre Celestial me ama " .
# Translation:
# Target:		After his remarks , the choir will sing : " My Heavenly Father Loves Me . "
#
# Spanish:	Para enriquecer la música , se requiere variedad : <unk> y <unk> , <unk> y bajos .
# Translation:
# Target:		It takes variety — <unk> and <unk> , <unk> and basses — to make rich music .
#
# Spanish:	<unk> , Marta fue a su casa para avisarle a María que el Señor había llegado .
# Translation:
# Target:		<unk> , Martha ran back to her home to tell Mary that the Lord had come .
#
# Spanish:	¿ Por qué <unk> a este pueblo que no habrá Cristo , para interrumpir su gozo ?
# Translation:
# Target:		Why do ye teach this people that there shall be no Christ , to interrupt their rejoicings ?
#
# Spanish:	No es sólo algo para conocerse y <unk> , sino que es algo para vivirse ” .
# Translation:
# Target:		It is not merely something to be known and studied , it is to be lived . ”
#
# Spanish:	Hablaba de su tamaño y forma , de cómo se podía <unk> , cargar o pasar .
# Translation:
# Target:		He talked about its size and shape , how it can be kicked , carried , or passed .
#
# Spanish:	Ustedes conocen las palabras : “ Iré y haré lo que el Señor ha mandado ” .
# Translation:
# Target:		You know the words : “ I will go and do the things which the Lord hath commanded . ”
#
# Spanish:	y con ella podré perseverar hasta el fin y estar con ella en la vida eterna .
# Translation:
# Target:		And with her , I will be able to endure to the end and be with her in eternal life .
#
# Spanish:	Los centros de reuniones de la Iglesia se convirtieron en refugios para miles de personas sin techo .
# Translation:
# Target:		Church meetinghouses became places of refuge to thousands of the homeless .
#
# Spanish:	Concluyo con las palabras de la primera estrofa del himno 324 en inglés , <unk> una palabra :
# Translation:
# Target:		I close quoting the first verse of hymn 324 , changing one word :
#
# Spanish:	Al tercer día <unk> lo que sabían era una nave de rescate pero esta pasó de largo .
# Translation:
# Target:		On the third day they spotted what they knew to be a rescue vessel .
#
# Spanish:	La frase era : " No lo sabes todo , ¡ pero sabes lo suficiente ! " .
# Translation:
# Target:		The phrase was " You do n’t know everything , but you know enough ! "
#
# Spanish:	¿ Y no hará Dios justicia a sus escogidos que claman a él día y noche … ?
# Translation:
# Target:		Shall not God avenge his own elect , which cry day and night unto him … ?
#
# Spanish:	Millones de personas han quedado desplazadas , e innumerables vidas se han visto <unk> por esos desafíos .
# Translation:
# Target:		Millions of people have been displaced , and countless lives have been disrupted by these challenges .
#
# Spanish:	Uno de los grandes desafíos de esta vida es tener fe en el tiempo oportuno del Señor .
# Translation:
# Target:		One of the hardest challenges in this life is to have faith in the Lord ’s timing .
#
# Spanish:	Cuando nos deleitamos en el día de reposo , es una señal de nuestro amor hacia Ellos .
# Translation:
# Target:		When we delight in the Sabbath day , it is a sign of our love for Them .
#
# Spanish:	Mi primer año como miembro del Cuórum de los Doce Apóstoles me ha hecho sentir muy humilde .
# Translation:
# Target:		My first year as a member of the Quorum of the Twelve Apostles has been most humbling .
#
# Spanish:	No pueden llegar a un entendimiento de una verdad espiritual con instrumentos que no la pueden detectar .
# Translation:
# Target:		You ca n’t come to an understanding of spiritual truth with instruments that are unable to detect it .
#
# Spanish:	Cuando le preguntamos a Él con fe y verdadera intención , Él nos revelará nuestras asignaciones divinas .
# Translation:
# Target:		When we ask Him in faith with real intent , He will reveal our divine assignments to us .
#
# Spanish:	Muy desilusionado , el joven dijo : “ Mi padre no sabría cómo darme una bendición ” .
# Translation:
# Target:		Very disappointed , the boy said , “ My father would n’t know how to give a blessing . ”
#
# Spanish:	La fe de Emily se manifestó <unk> en aquel momento tierno , justo cuando más lo necesitábamos .
# Translation:
# Target:		Emily ’s faith was showing — showing brightly — in that tender moment , right when we needed it most .
#
# Spanish:	<unk> a esos nuevos miembros porque creían que una vez satisfechas sus necesidades temporales , se <unk> .
# Translation:
# Target:		They <unk> these new members because they believed that once their temporal needs had been met , they would fall away .
#
# Spanish:	Sentía como si careciera de sentido y dirección , y no sabía a dónde ir para encontrarlos .
# Translation:
# Target:		I felt like I was adrift with no real purpose and direction , and I did n’t know where to go to find it .
#
# Spanish:	El Padre Celestial realmente sí se interesa , y escucha y contesta siempre cada oración de Sus hijos .
# Translation:
# Target:		Heavenly Father really does care and listen to and answer every child ’s prayer .
#
# Spanish:	No existe una barra de hierro de la verdad que mantenga a esa persona en el camino recto .
# Translation:
# Target:		There is no iron rod of truth to keep that person in the right way .
#
# Spanish:	Les asombra la maestría de la obra y la atención a los detalles de cada elemento del templo .
# Translation:
# Target:		They are impressed by the craftsmanship and attention to detail in every feature of a temple .
#
# Spanish:	Muchos sufren debido al abandono , el abuso , las adicciones , y las tradiciones y cultura incorrectas .
# Translation:
# Target:		Many are hurting because of neglect , abuse , addictions , and incorrect traditions and culture .
#
# Spanish:	Es el momento para nosotros , como Santos de los Últimos Días , de levantarnos y de testificar .
# Translation:
# Target:		It is time for us , as Latter - day Saints , to stand up and testify .
#
# Spanish:	( 19 ) El hermano de 16 años de un misionero brasileño trabaja para sostener a la familia .
# Translation:
# Target:		( 19 ) The 16-year - old brother of a Brazilian missionary works to support his family .
#
# Spanish:	Véanse , por ejemplo , 2 Nefi 9:25 ( Jacob ) y 2 Nefi 11:7 ( Nefi ) .
# Translation:
# Target:		See , for example , 2 Nephi 9:25 ( Jacob ) and 2 Nephi 11:7 ( Nephi ) .
#
# Spanish:	Cuando apenas tenía 19 meses , contrajo una enfermedad que no estaba diagnosticada , quedándose sorda y ciega .
# Translation:
# Target:		When just 19 months old , she suffered an <unk> illness that left her both deaf and blind .
#
# Spanish:	El presidente Thomas S. Monson , quien preside la conferencia , me ha pedido que dirija esta sesión .
# Translation:
# Target:		President Thomas S. Monson , who presides at the conference , has asked that I conduct this session .
#
# Spanish:	Todos los días se levantaba temprano por la mañana para estudiar las Escrituras durante más de dos horas ;
# Translation:
# Target:		He used to wake up early in the morning to study the scriptures for over two hours every day .
#
# Spanish:	Recordemos también que nuestros hijos y nietos <unk> nuestro amor por la cantidad de tiempo que les dedicamos .
# Translation:
# Target:		Let us remember that our children and grandchildren measure our love by how much devoted time we give them .
#
# Spanish:	Al seguir estrictamente su consejo , estaremos protegidos y recibiremos bendiciones selectas en nuestra jornada en esta tierra .
# Translation:
# Target:		By strictly following their counsel , we will be protected and receive choice blessings in our journey on this earth .
#
# Spanish:	Cuán indispensable es que ejerzamos una vigilancia constante a fin de evitar ceder a tales mentiras y tentaciones .
# Translation:
# Target:		How vital it is that we exercise constant <unk> in order to avoid giving in to such lies and temptations .
#
# Spanish:	Simplemente nos suplica que <unk> nuestros pecados y nos arrepintamos para que no tengamos que padecer como Él .
# Translation:
# Target:		He simply pleads with us to confess our sins and repent so that we will not have to suffer as He did .
#
# Spanish:	“ Hay mucha fortaleza en el libro , fortaleza que podemos imitar ” , dijo la hermana Beck .
# Translation:
# Target:		“ There ’s a lot of strength in the book — a lot of strength we can model , ” Sister Beck said .
#
# Spanish:	Me <unk> profundamente la forma en que los miembros de la Iglesia se ponen a disposición de los demás .
# Translation:
# Target:		I am deeply impressed by the way our Church members extend themselves to others .
#
# Spanish:	Cierto grado de sacrificio siempre ha estado asociado con la construcción de templos y con la asistencia al templo .
# Translation:
# Target:		Some degree of sacrifice has ever been associated with temple building and with temple attendance .
#
# Spanish:	Igual que el Salvador , él también exclamó : “ Oh Dios , ¿ en dónde estás ? ” .
# Translation:
# Target:		Like the Savior , he cried out , “ O God , where art thou ? ”
#
# Spanish:	¡ Qué les parece ! , teníamos que ir al <unk> en vez de llevarlo encima a todas partes .
# Translation:
# Target:		Imagine that — we had to go to it instead of carrying it around with us everywhere .
#
# Spanish:	Una luz en el cerro arriba de la playa y una segunda luz más abajo <unk> el estrecho paso .
# Translation:
# Target:		A light on the hill above the beach and a second lower light marked the narrow passage .
#
# Spanish:	Entonces , cuando Judas le pregunto , Él con calma le respondió , “ Tú lo has dicho ” .
# Translation:
# Target:		And when Judas asked Him the same question , He replied calmly , “ Thou hast said . ”
#
# Spanish:	Sentí que un importante mensaje para la Iglesia mundial <unk> la afirmación " El Señor confía en nosotros " .
# Translation:
# Target:		I felt an important message for the worldwide Church included the assertion " The Lord trusts us ! "
#
# Spanish:	Mi hija Katy sugirió que saliera y llamara a Susan para invitarla a ver la conferencia general ese día .
# Translation:
# Target:		My daughter Katy suggested that I leave and call Susan to invite her to watch general conference that day .
#
# Spanish:	Cuando nos enfrentamos a la adversidad y deseamos emular los atributos de Jesucristo , es esencial estar preparados espiritualmente .
# Translation:
# Target:		Being spiritually prepared means we have developed spiritual stamina or strength — we will be in good shape spiritually .
#
# Spanish:	Para la viuda de Sarepta el haber obedecido a Elías salvó su vida y básicamente la de su hijo .
# Translation:
# Target:		For the widow of Zarephath , obedience to Elijah saved her life and ultimately the life of her son .
#
# Spanish:	Si han sentido estas cosas antes , les pregunto hoy : " ¿ Pueden sentir esto ahora ? " .
# Translation:
# Target:		If you have felt these things before , I ask you today , " Can you feel so now ? "
#
# Spanish:	Un hombre abrió la puerta , me miró con enojo y luego me dijo a gritos que me marchara .
# Translation:
# Target:		The man opened the door , looked at me , scowled , and then barked at me to go away .
#
# Spanish:	El presidente McKay vestía un traje color crema y , con su <unk> cabello blanco , lucía muy distinguido .
# Translation:
# Target:		President McKay was dressed in a cream - colored suit and , with his <unk> white hair , looked very <unk> .
#
# Spanish:	Si no tienen un papá en casa , su responsabilidad de ministrar a su familia es aún más necesaria .
# Translation:
# Target:		If you do not have a father in your home , your responsibility to minister to your family is even more needed .
#
# Spanish:	Asistir al templo y <unk> en el espíritu del templo <unk> al servicio eficaz como misionero de tiempo completo .
# Translation:
# Target:		Going to the temple and having the spirit of the temple go through you precedes effective service as a full - time missionary .
#
# Spanish:	“ Me ha encantado trabajar para un cliente tan importante y en asuntos de gran <unk> ” , dijo .
# Translation:
# Target:		“ I have loved being able to work for such a great client and being able to work on such great issues , ” he said .
#
# Spanish:	El comprender la historia de la Sociedad de Socorro fortalece la identidad fundamental y el valor de la mujer fiel .
# Translation:
# Target:		Understanding the history of Relief Society strengthens the foundational identity and worth of faithful women .
#
# Spanish:	Véase Lola B. Walters , “ Sunshine in My Soul ” , Ensign , agosto de 1991 , pág. 19 .
# Translation:
# Target:		Lola B. Walters , “ Sunshine in My Soul , ” Ensign , Aug. 1991 , 19 .
#
# Spanish:	Allí , a veces , el velo entre nosotros y los que están al otro lado se vuelve muy tenue .
# Translation:
# Target:		Occasionally in the temple the veil between us and those on the other side becomes very thin .
#
# Spanish:	Debemos tender la mano a quienes se sienten solos , excluidos o que están al otro lado de la cerca .
# Translation:
# Target:		We need to reach out to those who feel alone , left behind , or outside the fence .
#
# Spanish:	Véase “ La Familia : Una Proclamación para el Mundo ” , Liahona , noviembre de 2010 , pág. 129 .
# Translation:
# Target:		“ The Family : A Proclamation to the World , ” Liahona and Ensign , Nov. 2010 , 129 .
#
# Spanish:	Al padre no le interesaba aprender sobre el Evangelio , pero no se opuso a que <unk> a su familia .
# Translation:
# Target:		The father was not interested in learning about the gospel but had no <unk> to our teaching his family .
#
# Spanish:	Como discípulos de Jesucristo , nuestro Maestro , se nos llama a apoyar y a sanar en vez de condenar .
# Translation:
# Target:		As disciples of Jesus Christ , our Master , we are called to support and heal rather than condemn .
#
# Spanish:	Tras escuchar a su padre hablar de sus muchas experiencias espirituales , Nefi quería saber lo que sabía su padre .
# Translation:
# Target:		After listening to his father speak of his many spiritual experiences , Nephi wanted to know what his father knew .
#
# Spanish:	Dale Carnegie , en , por ejemplo : Larry Chang , Wisdom for the Soul , 2006 , pág. 54 .
# Translation:
# Target:		Dale Carnegie , in , for example , Larry Chang , Wisdom for the Soul ( 2006 ) , 54 .
#
# Spanish:	¿ Pero qué pasa si en esa hoja de papel hay un segundo punto que represente al Libro de Mormón ?
# Translation:
# Target:		What happens , however , if on that piece of paper there is a second point representing the Book of Mormon ?
#
# Spanish:	“ Pues por cuanto él mismo padeció siendo tentado , es poderoso para socorrer a los que son tentados ” .
# Translation:
# Target:		“ For in that he himself hath suffered being tempted , he is able to succour them that are tempted . ”
#
# Spanish:	Sin embargo , las mujeres de esta dispensación son singulares debido a que esta dispensación es distinta de cualquier otra .
# Translation:
# Target:		Yet the women of this dispensation are distinct from the women of any other because this dispensation is distinct from any other .
#
# Spanish:	Al considerar el matrimonio , comprenderá que está eligiendo los padres de sus hijos y el legado que ellos tendrán .
# Translation:
# Target:		In considering marriage , he will see that he is choosing the parents of his children and the heritage they will have .
#
# Spanish:	El centrar nuestra vida en Jesucristo y Su evangelio nos brindará estabilidad y felicidad , como ilustra el ejemplo siguiente .
# Translation:
# Target:		Centering our lives in Jesus Christ and His gospel will bring stability and happiness to our lives , as the following examples illustrate .
#
# Spanish:	A veces estamos tentados a servir del modo que nosotros queremos y no precisamente del modo necesario en ese momento .
# Translation:
# Target:		Sometimes we are tempted to serve in a way that we want to serve and not necessarily in the way that is needed at the moment .
#
# Spanish:	Rápidamente vacié la bolsa y llevé el libro hasta la lamparilla , donde leí la forma de bendecir a los enfermos .
# Translation:
# Target:		I quickly emptied the bag and took the book to the night - light .
#
# Spanish:	Por la razón que sea , algunas veces , nosotros como líderes somos reacios a buscar y pedir ayuda a nuestros Amuleks ;
# Translation:
# Target:		For whatever reason , sometimes we as leaders are reluctant to find and ask our Amuleks .
#
# Spanish:	<unk> y mujer deben analizarlo juntos en oración con la comprensión de que son responsables ante Dios por las decisiones que tomen .
# Translation:
# Target:		Husbands and wives should prayerfully counsel together , understanding they are accountable to God for their decisions .
#
# Spanish:	( Si el padre está ausente , la madre debe pedir que la autoridad presidente que esté presente se haga cargo . )
# Translation:
# Target:		( If the father be absent , the mother should request the presiding authority present to take charge . )
#
# Spanish:	Thomas S. Monson , “ Atrévete a lo correcto aunque solo estés ” , Liahona , noviembre de 2011 , pág. 62 .
# Translation:
# Target:		Thomas S. Monson , “ Dare to Stand Alone , ” Ensign or Liahona , Nov. 2011 , 62 .
#
# Spanish:	La hermana Andrus me contó de los inicios de la Iglesia en Denton , comenzando con sus padres John y Margaret Porter .
# Translation:
# Target:		Sister Andrus told me of the early Church in Denton , beginning with her parents , John and Margaret Porter .
#
# Spanish:	Una hija fallecida es sellada a su familia después de que ella se le aparece a la esposa de una Autoridad General .
# Translation:
# Target:		A deceased daughter is sealed to her family after appearing in the temple to the wife of a General Authority .
#
# Spanish:	Tiempo después , leí en cuanto a Shiblón y agregué a mis metas la de llegar a ser más parecido a él .
# Translation:
# Target:		Later in my life , I learned about Shiblon and added to my life ’s goals to be more like him .
#
# Spanish:	Nosotros somos las manos del Señor aquí sobre la tierra , con el mandato de prestar servicio y edificar a Sus hijos .
# Translation:
# Target:		We are the Lord ’s hands here upon the earth , with the mandate to serve and to lift His children .
#
# Spanish:	Recordar cuando siendo solo un jovencito de doce años , enseñó y predicó a los doctores de la ley en el templo .
# Translation:
# Target:		To remember when , even as a 12-year - old boy , He taught and preached to the doctors in the temple .
#
# Spanish:	Vi por mí mismo el poder y la bendición del repetido llamado de los profetas para que cada miembro sea un misionero .
# Translation:
# Target:		I saw for myself the power and the blessing in the repeated call of prophets for every member to be a missionary .
#
# Spanish:	Haríamos bien en buscar respuesta a nuestros problemas y preguntas investigando lo que el Señor ha revelado por conducto de Sus profetas .
# Translation:
# Target:		We would do well to search out answers to our problems and questions by investigating what the Lord has revealed through His prophets .
#
# Spanish:	Ustedes ahora tienen cómodamente a su alcance los sagrados anales que los profetas , sacerdotes y reyes atesoraron , estimaron y <unk> .
# Translation:
# Target:		You now have easily within your reach the sacred record that prophets , priests , and kings treasured , embraced , and preserved !
#
# Spanish:	En esta creciente conmoción espiritual , el Evangelio restaurado seguirá adelante proporcionando la norma , el ideal y el modelo del Señor .
# Translation:
# Target:		In this increasing spiritual commotion , the restored gospel will continue to carry the standard , the ideal , the pattern of the Lord .
#
# Spanish:	<unk> que la autoridad dada por el Salvador y el don del Espíritu Santo eran esenciales para el establecimiento de Su Iglesia .
# Translation:
# Target:		They understood that the authority given by the Savior and the gift of the Holy Ghost were essential for the establishment of His Church .
#
# Spanish:	Los que decidan escuchar y prestar atención a las palabras del Señor , proporcionadas mediante Sus profetas , hallarán seguridad y paz .
# Translation:
# Target:		Those who choose to listen and give heed to the words of the Lord , as delivered through His prophets , will find safety and peace .
#
# Spanish:	Es una fuente de fortaleza y ánimo saber quiénes somos , qué tenemos y qué debemos hacer en la obra del Todopoderoso .
# Translation:
# Target:		It is a source of strength and encouragement to know who we are and what we have and what we must do in the work of the Almighty .
#
# Spanish:	“ El profético plan de bienestar no es solamente una interesante nota al pie de la página de la historia de la Iglesia .
# Translation:
# Target:		“ The prophetic welfare plan is not merely an interesting footnote in the history of the Church .
#
# Spanish:	Si el perseverar hasta el fin es esencial para obtener la vida eterna , ¿ por qué tenemos que luchar para ser fieles ?
# Translation:
# Target:		If enduring to the end is essential to eternal life , why do we struggle to be faithful ?
#
# Spanish:	Nosotros sonreímos y recordamos que Dios tiene la determinación de hacer de nosotros más de lo que pensábamos que podríamos llegar a ser .
# Translation:
# Target:		We smile and remember that God is determined to make of us more than we thought we could be .
#
# Spanish:	Una mayor cantidad de ustedes , jóvenes y jovencitas , se <unk> a esta ola al procurar vivir dignos de recibir llamamientos misionales .
# Translation:
# Target:		More of you young men and women will catch this wave as you strive to be worthy of mission calls .
#
# Spanish:	Quizás más importante aún es que ustedes ministran cuando ayudan a su padre en sus deberes como el líder espiritual de su hogar .
# Translation:
# Target:		Perhaps most important , you minister as you assist your father in his duties as the spiritual leader in your home .
#
# Spanish:	El Señor usa esta Iglesia como una herramienta para atraer a Sus hijos en todo el mundo hacia la protección de Su Evangelio .
# Translation:
# Target:		The Lord uses this Church as a tool in pulling His children throughout the world toward the protection of His gospel .
#
# Spanish:	Véase Stephanie Nebehay , “ World ’s Refugees and Displaced Exceed Record 60 Million ” , 18 de diciembre de 2015 , reuters.com .
# Translation:
# Target:		See Stephanie Nebehay , “ World ’s Refugees and Displaced Exceed Record 60 Million , ” Dec. 18 , 2015 , reuters.com .
#
# Spanish:	Queremos seguir al Salvador declarando con sencillez y claridad , y a la vez con humildad , que somos miembros de Su Iglesia .
# Translation:
# Target:		We want to follow the Savior by simply and clearly , yet humbly , declaring that we are members of His Church .
#
# Spanish:	Afortunadamente , no resulté herido , y cuatro horas más tarde sentí alivio al enterarme de que toda mi familia estaba a salvo .
# Translation:
# Target:		Fortunately , I was not injured , and four hours later , I was relieved to learn that my entire family was safe .
#
# Spanish:	En el escenario eterno de Dios , normalmente se espera que los padres sean los personajes principales en la vida de sus hijos .
# Translation:
# Target:		On God ’s eternal stage , it is usually intended that parents act as the central cast members in their children ’s lives .
#
# Spanish:	Evitemos la desesperación y el pesar de los que caen en el cautiverio y ya no pueden soportar cantar los cánticos de Sión .
# Translation:
# Target:		Let us avoid the despair and sorrow of those who fall into captivity and can no longer bear to sing the songs of Zion .
#
# Spanish:	Caroline sabía que la ayudaríamos y , al buscar las cosas buenas que nos rodeaban y entonar canciones , nos sentimos más felices .
# Translation:
# Target:		Caroline knew we would help her , and as we looked for the good things around us and sang songs , we felt happier .
#
# Spanish:	Hablamos con intrepidez porque Satanás es un ser real <unk> en <unk> y ustedes enfrentan su influencia a una edad cada vez menor .
# Translation:
# Target:		We speak boldly because Satan is a real being set on destroying you , and you face his influence at a younger and younger age .
